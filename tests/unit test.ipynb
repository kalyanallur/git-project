# %%
from pyspark.sql import DataFrame
from pyspark.sql.functions import col
from notebooks.utils import filter_valid_age

# %%
data = [
    (25, "Alice",     "New York"),
    (None, "Bob",      "Los Angeles"),
    (22, "Charlie",   "Chicago"),
    (28, "Diana",     "Houston"),
    (35, "Evan",      "Phoenix"),
    (27, "Fiona",     "Philadelphia"),
    (32, "George",    "San Antonio"),
    (29, "Hannah",    "San Diego"),
    (31, "Ian",       "Dallas"),
    (26, "Julia",     "San Jose")
]
df = spark.createDataFrame(data, schema="Age INT, Name STRING, City STRING")


def test_age_filter(df:DataFrame):
    result = filter_valid_age(df)
    count = result.count()
    assert count==9, f"Expected 9 valid rows but found {count}"

test_age_filter(df)

# %%
# ""
